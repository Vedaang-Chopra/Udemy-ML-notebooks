# %%
import pandas as pd
import json

# %%
dat=list()
with open ('../MISSION Machine Learning Datasets/midha.json', 'r') as f:
    for l in f.readlines():
        if not l.strip (): # skip empty lines
            continue

        json_data = json.loads (l)
        dat.append(json_data)

# %%
dat[1000]['filter_level']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-aa2f8b418c74> in <module>()
# ----> 1 dat[:,:]['filter_level']
#
# TypeError: list indices must be integers or slices, not tuple

# %%
for keys in dat[0]:
    print(keys)
# Out:
# created_at
# id
# id_str
# text
# source
# truncated
# in_reply_to_status_id
# in_reply_to_status_id_str
# in_reply_to_user_id
# in_reply_to_user_id_str
# in_reply_to_screen_name
# user
# geo
# coordinates
# place
# contributors
# retweeted_status
# quoted_status_id
# quoted_status_id_str
# quoted_status
# quoted_status_permalink
# is_quote_status
# quote_count
# reply_count
# retweet_count
# favorite_count
# entities
# favorited
# retweeted
# filter_level
# lang
# timestamp_ms

# %%
df = pd.DataFrame(dat)

# %%
df.head()
# Out:
#   contributors coordinates                      created_at display_text_range  \
# 0         None        None  Wed Nov 27 09:31:42 +0000 2019                NaN
# 1         None        None  Wed Nov 27 09:31:43 +0000 2019                NaN
# 2         None        None  Wed Nov 27 09:31:46 +0000 2019                NaN
# 3         None        None  Wed Nov 27 09:31:47 +0000 2019                NaN
# 4         None        None  Wed Nov 27 09:31:48 +0000 2019                NaN
#
#                                             entities extended_entities  \
# 0  {'hashtags': [], 'urls': [], 'user_mentions': ...               NaN
# 1  {'hashtags': [], 'urls': [], 'user_mentions': ...               NaN
# 2  {'hashtags': [], 'urls': [], 'user_mentions': ...               NaN
# 3  {'hashtags': [], 'urls': [], 'user_mentions': ...               NaN
# 4  {'hashtags': [], 'urls': [], 'user_mentions': ...               NaN
#
#   extended_tweet  favorite_count  favorited filter_level  \
# ...

# %%
#library for setting the regular epression
import re

# %%
tweet = re.sub('[^a-zA-Z0-9%]', ' ', df['text'][0])

# %%
tweet
# Out:
# 'RT  Agent0fChaos   So by only 3% Brahmins Devendra Fadanvis got 122 seats in 2014 and 105  seats in 2019 Maharashtra elections  How   These '

# %%
# downloading stopwords from nltk library
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\rahul
# [nltk_data]     midha\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#splitting the string
tweet = tweet.split()

# %%
tweet
# Out:
# ['RT',
#  'Agent0fChaos',
#  'So',
#  'by',
#  'only',
#  '3%',
#  'Brahmins',
#  'Devendra',
#  'Fadanvis',
#  'got',
#  '122',
#  'seats',
#  'in',
#  '2014',
#  'and',
#  '105',
#  'seats',
#  'in',
#  '2019',
#  'Maharashtra',
#  'elections',
#  'How',
#  'These']

# %%
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
tweet = [ps.stem(word) for word in tweet if not word in set(stopwords.words('english'))]

# %%
tweet
# Out:
# ['RT',
#  'agent0fchao',
#  'So',
#  '3%',
#  'brahmin',
#  'devendra',
#  'fadanvi',
#  'got',
#  '122',
#  'seat',
#  '2014',
#  '105',
#  'seat',
#  '2019',
#  'maharashtra',
#  'elect',
#  'how',
#  'these']

# %%
tweet = ' '.join(tweet)

# %%
tweet
# Out:
# 'RT agent0fchao So 3% brahmin devendra fadanvi got 122 seat 2014 105 seat 2019 maharashtra elect how these'

# %%
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
corpus = []
for i in range (0,1000):
    tweet = re.sub('[^a-zA-Z]', ' ', df['text'][i])
    tweet = tweet.lower()
    tweet = tweet.split()
    s = PorterStemmer()
    tweet = [ps.stem(word) for word in tweet if not word in set(stopwords.words('english'))]
    review = ' '.join(tweet)
    corpus.append(tweet)
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\rahul
# [nltk_data]     midha\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
corpus
# Out:
# [['rt',
#   'agent',
#   'fchao',
#   'brahmin',
#   'devendra',
#   'fadanvi',
#   'got',
#   'seat',
#   'seat',
#   'maharashtra',
#   'elect'],
#  ['rt',
#   'gautambhatia',
#   'way',
#   'anyon',
#   'know',
#   'happen',
#   'social',
#   'boycott',
#   'law',
#   'pass',
#   'earli',
#   'phase',
#   'devendra',
#   'fa'],
#  ['rt',
#   'erbmjha',
#   'shivsena',
#   'back',
#   'stab',
#   'amit',
#   'shah',
#   'amp',
#   'narendra',
#   'modi',
#   'ji',
#   'clearli',
#   'said',
#   'mani',
#   'time',
#   'devendra',
#   'fadnavi'],
#  ['rt',
#   'flawsom',
#   'guy',
#   'devendra',
#   'fadnavi',
#   'alexa',
#   'make',
#   'feel',
#   'good',
#   'play',
#   'song',
#   'alexa',
#   'play',
#   'udd',
#   'gay',
#   'tote',
#   'tere',
#   'udd',
#   'gay',
#   'tote'],
#  ['rt',
#   'abhishbanerj',
#   'yeah',
#   'chanakya',
#   'sharad',
#   'pawar',
#   'youngest',
#   'cm',
#   'maharashtra',
#   'lead',
#   'small',
#   'region',
#   'parti',
#   'never',
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 1500)
X = cv.fit_transform(corpus).toarray()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-0e5808991301> in <module>()
#       1 from sklearn.feature_extraction.text import CountVectorizer
#       2 cv = CountVectorizer(max_features = 1500)
# ----> 3 X = cv.fit_transform(corpus).toarray()
#
# C:\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#     867
#     868         vocabulary, X = self._count_vocab(raw_documents,
# --> 869                                           self.fixed_vocabulary_)
#     870
#     871         if self.binary:
#
# C:\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in _count_vocab(self, raw_documents, fixed_vocab)
#     790         for doc in raw_documents:
#     791             feature_counter = {}
# --> 792             for feature in analyze(doc):
#     793                 try:
# ...
